# %%
import numpy as np

# %%
import pandas as pd
import pickle

# %%
data1 = pd.read_csv('user_ratings.csv')

# %%
data1
# Out:
#      User                        Product  Rating
# 0       1                    HP Pavilion       4
# 1       1                         HP 15s       3
# 2       1                 Lenovo IdeaPad       5
# 3       1             Lenovo Yoga Slim 7       4
# 4       1                 Dell 15 Laptop       3
# ..    ...                            ...     ...
# 255     5  Portronics Harmonics Twins S3       3
# 256     5                Earboss AirDoze       3
# 257     5              boAt Airdopes 192       3
# 258     5        Boult Audio Airbass Z35       4
# 259     5             realme Buds Air 3S       4
#
# [260 rows x 3 columns]

# %%
avg_rating_df=data1.groupby('Product').mean()['Rating'].reset_index()
avg_rating_df.rename(columns={'Rating':'avg-ratings'},inplace=True)
avg_rating_df
# Out:
#                           Product  avg-ratings
# 0        APPLE MacBook Pro M2 Pro          4.0
# 1                 APPLE iPhone 12          5.0
# 2                 APPLE iPhone 13          5.0
# 3            APPLE iPhone 14 Plus          5.0
# 4             ASUS TUF Gaming F15          4.0
# 5                ASUS Vivobook 15          3.4
# 6               ASUS Vivobook 16X          4.0
# 7              Acer Aspire 3 Core          3.4
# 8                   Acer Aspire 7          3.4
# 9                   Acer One Core          2.4
# 10           Apple MacBook AIR M2          5.0
# 11           Apple Macbook Air M1          4.6
# 12        Boult Audio Airbass Z35          4.0
# 13                 Dell 15 Laptop          3.4
# 14                       Dell G15          4.0
# 15                Earboss AirDoze          3.0
# 16                         HP 15s          3.4
# 17                    HP Pavilion          4.4
# 18               HP Pavilion Plus          4.4
# ...

# %%
popular_df=avg_rating_df
popular_df
# Out:
#                           Product  avg-ratings
# 0        APPLE MacBook Pro M2 Pro          4.0
# 1                 APPLE iPhone 12          5.0
# 2                 APPLE iPhone 13          5.0
# 3            APPLE iPhone 14 Plus          5.0
# 4             ASUS TUF Gaming F15          4.0
# 5                ASUS Vivobook 15          3.4
# 6               ASUS Vivobook 16X          4.0
# 7              Acer Aspire 3 Core          3.4
# 8                   Acer Aspire 7          3.4
# 9                   Acer One Core          2.4
# 10           Apple MacBook AIR M2          5.0
# 11           Apple Macbook Air M1          4.6
# 12        Boult Audio Airbass Z35          4.0
# 13                 Dell 15 Laptop          3.4
# 14                       Dell G15          4.0
# 15                Earboss AirDoze          3.0
# 16                         HP 15s          3.4
# 17                    HP Pavilion          4.4
# 18               HP Pavilion Plus          4.4
# ...

# %%
popular_df=popular_df.sort_values('avg-ratings',ascending=False)

# %%
popular_df=popular_df.head(9)
popular_df
# Out:
#                         Product  avg-ratings
# 2               APPLE iPhone 13          5.0
# 3          APPLE iPhone 14 Plus          5.0
# 44             Xiaomi 12 Pro 5G          5.0
# 10         Apple MacBook AIR M2          5.0
# 1               APPLE iPhone 12          5.0
# 41  SAMSUNG Galaxy S22 Ultra 5G          5.0
# 19               Lenovo IdeaPad          4.6
# 11         Apple Macbook Air M1          4.6
# 26                 MSI Bravo 15          4.4

# %%
pickle.dump(popular_df,open('popular.pkl','wb'))
