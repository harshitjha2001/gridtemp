# %%
import numpy as np

# %%
import pandas as pd
import pickle

# %%
data = pd.read_csv('user_ratings.csv')

# %%
data
# Out:
#      User                        Product  Rating
# 0       1                    HP Pavilion       4
# 1       1                         HP 15s       3
# 2       1                 Lenovo IdeaPad       5
# 3       1             Lenovo Yoga Slim 7       4
# 4       1                 Dell 15 Laptop       3
# ..    ...                            ...     ...
# 255     5  Portronics Harmonics Twins S3       3
# 256     5                Earboss AirDoze       3
# 257     5              boAt Airdopes 192       3
# 258     5        Boult Audio Airbass Z35       4
# 259     5             realme Buds Air 3S       4
#
# [260 rows x 3 columns]

# %%
pt =data.pivot_table(index='Product',columns='User',values='Rating')
pt
# Out:
# User                           1  2  3  4  5
# Product
# APPLE MacBook Pro M2 Pro       4  4  4  4  4
# APPLE iPhone 12                5  5  5  5  5
# APPLE iPhone 13                5  5  5  5  5
# APPLE iPhone 14 Plus           5  5  5  5  5
# ASUS TUF Gaming F15            4  4  4  4  4
# ASUS Vivobook 15               3  4  3  4  3
# ASUS Vivobook 16X              4  4  4  4  4
# Acer Aspire 3 Core             3  4  3  4  3
# Acer Aspire 7                  3  4  3  4  3
# Acer One Core                  2  3  2  3  2
# Apple MacBook AIR M2           5  5  5  5  5
# Apple Macbook Air M1           5  5  4  5  4
# Boult Audio Airbass Z35        4  4  4  4  4
# Dell 15 Laptop                 3  4  3  4  3
# Dell G15                       4  4  4  4  4
# Earboss AirDoze                3  3  3  3  3
# HP 15s                         3  4  3  4  3
# HP Pavilion                    4  5  4  5  4
# HP Pavilion Plus               4  5  4  5  4
# Lenovo IdeaPad                 5  5  4  5  4
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (52, 52)

# %%
def recommendx(prod):
    index = np.where(pt.index == prod)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)

    recommended_products = []
    count = 0 
    for i in similar_items:
        if pt.index[i[0]] != prod:  
            recommended_products.append(pt.index[i[0]])
            count += 1
            if count >= 3:  
                break
    
    return recommended_products

recommended_products = recommendx('HP Pavilion')
print("Recommended Products:")
for product in recommended_products:
    print(product)
# Out:
# Recommended Products:
# HP Pavilion Plus
# MSI Bravo 15
# ASUS Vivobook 15

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
pickle.dump(recommended_products,open('recommended_products.pkl','wb'))

# %%
recommendx('APPLE MacBook Pro M2 Pro')
# Out:
# ['APPLE iPhone 12', 'APPLE iPhone 13', 'APPLE iPhone 14 Plus']

# %% [markdown]
# recommend('Apple Mac Air')
