# %%
import numpy as np

# %%
import pandas as pd
import pickle

# %%
data1 = pd.read_csv('user_ratings.csv')

# %%
data1
# Out:
#     User                   Product  Rating
# 0      1                 HP Laptop       5
# 1      1            Samsung Mobile       5
# 2      1               Dell Laptop       0
# 3      1              Apple Mobile       0
# 4      1             Lenovo Laptop       0
# 5      1             Xiaomi Mobile       0
# 6      1               Acer Laptop       0
# 7      1            OnePlus Mobile       5
# 8      1                MSI Laptop       0
# 9      1       Google Pixel Mobile       0
# 10     1               Asus Laptop       0
# 11     1               Sony Mobile       0
# 12     1                 LG Mobile       0
# 13     1            Samsung Laptop       0
# 14     1          Beats Headphones       0
# 15     1  Microsoft Surface Laptop       0
# 16     1         Google Pixel Buds       0
# 17     1  OnePlus Bullets Wireless       0
# 18     1        Sony Xperia Mobile       0
# 19     1              Apple iPhone       0
# 20     1       Samsung Galaxy Buds       0
# ...

# %%
num_rating_df=data1.groupby('Product').count()['Rating'].reset_index()
num_rating_df.rename(columns={'Rating':'num-ratings'},inplace=True)
num_rating_df
# Out:
#                      Product  num-ratings
# 0            ASUS ROG Laptop            2
# 1                Acer Laptop            2
# 2               Apple Mobile            2
# 3               Apple iPhone            2
# 4                Asus Laptop            2
# 5           Beats Headphones            2
# 6                Dell Laptop            2
# 7          Google Pixel Buds            2
# 8        Google Pixel Mobile            2
# 9                  HP Laptop            2
# 10    Jabra Wireless Headset            2
# 11                 LG Mobile            2
# 12             Lenovo Laptop            2
# 13  Logitech Bluetooth Mouse            2
# 14                MSI Laptop            2
# 15  Microsoft Surface Laptop            2
# 16  OnePlus Bullets Wireless            2
# 17            OnePlus Mobile            2
# 18       Samsung Galaxy Buds            2
# 19            Samsung Laptop            2
# 20            Samsung Mobile            2
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (25, 25)

# %%
# Out:
# Recommended Products:
# HP Laptop
# Samsung Mobile
# ASUS ROG Laptop

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
pickle.dump(recommended_products,open('recommended_products.pkl','wb'))

# %%
recommendx('samsung Mobile')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 recommendx('samsung Mobile')
#
# Cell In[63], line 2, in recommendx(prod)
#       1 def recommendx(prod):
# ----> 2     index = np.where(pt.index == prod)[0][0]
#       3     similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:4]
#       5     recommended_products = []
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# recommend('Apple Mac Air')
